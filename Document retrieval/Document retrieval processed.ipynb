# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from gensim import similarities

import math
import time
import datetime
import numpy as np

from scipy import spatial
import ast

from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff

from sklearn.metrics import classification_report
from sklearn.metrics import PrecisionRecallDisplay

import gensim
import nltk
from nltk.tokenize import sent_tokenize
import string
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from openai.embeddings_utils import cosine_similarity

from gensim.models import Word2Vec
from gensim import similarities
from sklearn.metrics.pairwise import cosine_similarity
from openai.embeddings_utils import cosine_similarity, get_embedding
import tensorflow as tf
import tensorflow_hub as hub

# %% [markdown]
# ## Embed sentence

# %%
df = pd.read_excel('amazon_review JOIN.xlsx')

# %%
df['Review Content new'] = df['Review Content'].apply(lambda x: str(x) if x is not None else '')

# %%
def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = text.lower()
    return text

df['Cleaned Reviews'] = df['Review Content new'].apply(clean_text)

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# %%
df['Final Reviews'] = df['Cleaned Reviews'].apply(remove_stopwords)

# %%
# def split_text(text):
#     sentences = sent_tokenize(str(text))
#     return sentences 

# def remove_punc(text):
#     remove = str.maketrans('','',string.punctuation)
#     remove_punc = [sentence.translate(remove) for sentence in text]
#     return remove_punc

def brand(model):
    match = re.search(r'^(HP|Epson|Canon)', model, re.IGNORECASE)
    if match:
        return match.group(0)

# %%
df['Brand'] = df['Review Model'].apply(brand)
# df['Review Content split'] =  df['Review Content'].apply(split_text)

# %%
df.head(2)
# Out:
#              Review Model Retailer              Comp Model Review date  \
# 0     Canon Pixma TS6420a   Amazon                     NaN  2023-08-10
# 1  HP OfficeJet Pro 9015e   Amazon  Epson - Workforce 4820  2022-06-04
#
#        Review name  Review rating             Review title  \
# 0  Ernest Birkholz              5              Works great
# 1           mattey              3  spunky mid size printer
#
#                                       Review Content Verified Purchase or not  \
# 0             🖨 was easy to install and works great.        Verified Purchase
# 1  🔆Slower print speed than what I’m used to (old...        Verified Purchase
#
#    People_find_helpful vine or not  \
# 0                  NaN         NaN
# 1                  NaN         NaN
#
#                                                  URL  list price  \
# 0  https://www.amazon.com/product-reviews/B09TG52...      129.99
# 1  https://www.amazon.com/product-reviews/B08QR6P...      289.99
#
#    rating count  overall rating  Brand  \
# 0           285             4.2  Canon
# 1           285             4.2     HP
#
#                                   Review Content new  \
# 0             🖨 was easy to install and works great.
# 1  🔆Slower print speed than what I’m used to (old...
#
#                                      Cleaned Reviews  \
# 0                was easy to install and works great
# 1  slower print speed than what im used to old mo...
#
#                                        Final Reviews
# 0                           easy install works great
# 1  slower print speed im used old modelhpojpro ne...

# %%
model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

def embed(text,model):
    embeddings = model(text)
    return [embedding.numpy() for embedding in embeddings]


df['Embed_sentence'] = embed(df['Final Reviews'], model)

# %%
df['Embed_sentence']
# Out:
# 0        [-0.047439758, -0.03413595, -6.694528e-05, 0.0...
# 1        [-0.07037805, -0.06696488, -0.07535003, 0.0402...
# 2        [-0.035656825, -0.033195715, 0.07047429, 0.073...
# 3        [-0.04945306, -0.064851016, -0.0635704, 0.0535...
# 4        [-0.016937636, -0.046409328, -0.05469985, 0.05...
#                                ...
# 10204    [0.024017375, -0.0698705, 0.0030025216, 0.0155...
# 10205    [0.024017375, -0.0698705, 0.0030025216, 0.0155...
# 10206    [0.024017375, -0.0698705, 0.0030025216, 0.0155...
# 10207    [0.024017375, -0.0698705, 0.0030025216, 0.0155...
# 10208    [0.024017377, -0.06987051, 0.0030025218, 0.015...
# Name: Embed_sentence, Length: 10209, dtype: object

# %%
# df.to_csv('amazon_review_embedded.csv')
# df = pd.read_csv('amazon_review_embedded.csv')

# df['Embed_sentence'] = df['Embed_sentence'].apply(np.array)
# df['Embed_sentence'] = df['Embed_sentence'].apply(eval)

# %% [markdown]
# # Find related reviews

# %%
topics_samples= [
    'Setup', 
    'Connectivity', 
    'Customer Support', 
    'Print Quality', 
    'Print Speed', 
    'Ink supply and Cartridge', 
    'Printer Hardware Robustness and sturdiness', 
#     'Control Panel', 
    'Ease of Use', 
#     'Firmware', 
    'Business Services and Subscription', 
     'Paper jam'
]

# %%
def embed_label(text,model):
    embeddings = model([text])
    return embeddings.numpy()[0]

text = 'Connectivity'
input_embedding_vector = embed_label(text,model)

df['similarity'] = df['Embed_sentence'].apply(lambda x: cosine_similarity(input_embedding_vector,x))

# %%
pd.set_option('display.max_colwidth', None)
df_new = df.sort_values(by = 'similarity',ascending = False)
columns = ['Brand','Review Model','Review rating','Review Content']
df_select = df_new[columns]
df_final = df_select[df_select['Brand'] == 'HP'].head(4).reset_index(drop = True)
df_final
# Out:
#   Brand           Review Model  Review rating  \
# 0    HP     HP Smart Tank 6001              1
# 1    HP  HP ENVY Inspire 7955e              5
# 2    HP       HP DeskJet 2755e              5
# 3    HP     HP Smart Tank 7301              2
#
#                           Review Content
# 0                    Connection problems
# 1                     So easy to connect
# 2  Connected to devices with no problem.
# 3       wireless will not stay connected

# %%
text = 'Print Quality'
input_embedding_vector = embed_label(text,model)

df['similarity'] = df['Embed_sentence'].apply(lambda x: cosine_similarity(input_embedding_vector,x))

pd.set_option('display.max_colwidth', None)
df_new = df.sort_values(by = 'similarity',ascending = False)
columns = ['Brand','Review Model','Review rating','Review Content']
df_select = df_new[columns]
df_final = df_select[df_select['Brand'] == 'HP'].head(4).reset_index(drop = True)
df_final
# Out:
#   Brand            Review Model  Review rating  \
# 0    HP   HP ENVY Inspire 7955e              5
# 1    HP  HP OfficeJet Pro 9025e              5
# 2    HP           HP ENVY 6055e              5
# 3    HP           HP ENVY 6455e              5
#
#                                   Review Content
# 0     I have been pleased with the print quality
# 1    Print quality exactly. Best one I have had.
# 2  The print quality is good. I am very pleased.
# 3                     Excellent print quality !!

# %%
text = 'Paper jam'
input_embedding_vector = embed_label(text,model)

df['similarity'] = df['Embed_sentence'].apply(lambda x: cosine_similarity(input_embedding_vector,x))

pd.set_option('display.max_colwidth', None)
df_new = df.sort_values(by = 'similarity',ascending = False)
columns = ['Brand','Review Model','Review rating','Review Content']
df_select = df_new[columns]
df_final = df_select[df_select['Brand'] == 'HP'].head(4).reset_index(drop = True)
df_final
# Out:
#   Brand            Review Model  Review rating  \
# 0    HP           HP ENVY 6455e              4
# 1    HP  HP OfficeJet Pro 8034e              5
# 2    HP  HP OfficeJet Pro 9015e              3
# 3    HP  HP OfficeJet Pro 8025e              2
#
#                                                                                                                                                                                                                                                                                                                                                      Review Content
# 0                                                                                                                                                                                                                                                                                                                                                Paper tends to jam
# 1                                                                                                                                                                                                                                                                                                                                           the paper feed in front
# 2                                                                                                                                                                                                                                                                                       what can I do, this printer continues to have paper jams and is not working
# 3  If you print something? Paper jams. Reload the paper the only way it can go? Paper jam.WiFi blinks? Paper jam. You leave the printer alone too long? Paper jam. It’s incredible how hard it must be to make a printer that just prints when it’s told to, because no one can seem to do it. I’ve had this for 3 months and it’s a very high maintenance printer.

# %% [markdown]
# # Other (Draft)

# %%
# labels = [
#     'Setup', 
#     'Connectivity', 
#     'Customer Support', 
#     'Print Quality', 
#     'Print Speed', 
#     'Ink supply and Cartridge', 
#     'Printer Hardware Robustness and sturdiness', 
#     'Control Panel', 
#     'Ease of Use', 
#     'Firmware', 
#     'Business Services and Subscription', 
#      'Paper jam',
#      'Control Panel', 
#     'Other'
# ]

# df_labels = pd.DataFrame({'Labels': labels})
# df_labels

# %%
# def docs2vecs(docs,dictionary):
#     vec1 = [dictionary.doc2bow(doc) for doc in docs]
#     tfid = gensim.models.TfidfModel(vec1)
#     vec2 = [tfidf[vec] for vec in vec1]
#     return vec2

# vectorizer = TfidfVectorizer(max_df = 0.5, min_df = 2, stop_words = 'english')
# X = vectorizer.fit_transform(dataset.data)

# %%
# model = Word2Vec(sentences = label_token, vector_size=100, window=5, min_count=1, sg=0)

# %%
# from gensim.models import Word2Vec
# import pandas as pd

# # List of labels
# labels = [
#     'Setup', 
#     'Connectivity', 
#     'Customer Support', 
#     'Print Quality', 
#     'Print Speed', 
#     'Ink supply and Cartridge', 
#     'Printer Hardware Robustness and sturdiness', 
#     'Control Panel', 
#     'Ease of Use', 
#     'Firmware', 
#     'Business Services and Subscription', 
#     'Paper jam',
#     'Control Panel', 
#     'Other'
# ]

# # Create a DataFrame with labels
# df_labels = pd.DataFrame({'Labels': labels})

# # Split the labels into words (tokens)
# label_tokens = [label.split() for label in labels]

# # Train a Word2Vec model on label tokens
# model = Word2Vec(sentences=label_tokens, vector_size=100, window=5, min_count=1, sg=0)

# # Function to get the embedding of a label
# def label_embedding(label, model):
#     return model.wv[label]  # Use indexing to retrieve the embedding

# # Apply the label_embedding function to embed labels
# df_labels['Label Embeddings'] = df_labels['Labels'].apply(lambda x: label_embedding(x, model))

# %%
# def search_reviews(df, product_description, pprint=True):
#     product_embedding = get_embedding(
#         product_description,
#         engine=embedding_model
#     )
#     df[f"similarity_{product_description}"] = df.embedding.apply(lambda x: cosine_similarity(x, product_embedding))

#     results = df.sort_values(f"similarity_{product_description}", ascending=False)
                       
#     return results



# summary_df = []

# for label in labels:
#     label_results = search_reviews(df_filter, label, pprint=True)
    
#     # Apply a similarity threshold to filter rows
#     threshold = 0.85
#     filtered_results = label_results[label_results[f"similarity_{label}"] > threshold]
    
#     # Add the label column to the filtered results
#     filtered_results['topic'] = label
    
#     # Append the filtered results to the summary_df
#     summary_df.append(filtered_results)
    
#     time.sleep(5)

# # Concatenate the filtered results into the final summary DataFrame
# summary_df = pd.concat(summary_df)

# %%
# columns_to_drop = ['embedding', 'embedding_splitted']

# # Use the drop method to remove the specified columns
# df_phrase_filtered = df_phrase.drop(columns=columns_to_drop)

# %%
df_filter = df_filter.drop_duplicates(subset = ['Review Model', 'key phrase splitted'])

# %%
def find_most_similar_word(review_embedding, word_vectors, word_list):
    similarities = [cosine_similarity(review_embedding, word_vector) for word_vector in word_vectors]
    most_similar_index = similarities.index(max(similarities))
    return word_list[most_similar_index]  # Return the actual word

# Assuming you have a DataFrame 'df' with 'embedding' column containing review embeddings
df_phrase['Topic'] = df_phrase['embedding_splitted'].apply(lambda x: find_most_similar_word(x, label_embeddings, labels))
# Out:
# C:\Users\YeTi985\AppData\Local\Temp\ipykernel_17244\3029389664.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_phrase['Topic'] = df_phrase['embedding_splitted'].apply(lambda x: find_most_similar_word(x, label_embeddings, labels))

# %%
df_phrase['Topic2'] = df_phrase['embedding'].apply(lambda x: find_most_similar_word(x, label_embeddings, labels))
# Out:
# C:\Users\YeTi985\AppData\Local\Temp\ipykernel_17244\3720456180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_phrase['Topic2'] = df_phrase['embedding'].apply(lambda x: find_most_similar_word(x, label_embeddings, labels))

# %%
df_phrase
# Out:
#        Unnamed: 0            Review Model Retailer Review date  Review rating  \
# 6388         6388  HP OfficeJet Pro 9025e   Amazon  2021-05-07              3
# 6389         6389  HP OfficeJet Pro 9025e   Amazon  2021-05-07              3
# 6390         6390  HP OfficeJet Pro 9025e   Amazon  2021-05-07              3
# 6391         6391  HP OfficeJet Pro 9025e   Amazon  2021-05-07              3
# 6401         6401  HP OfficeJet Pro 9025e   Amazon  2023-03-03              5
# ...           ...                     ...      ...         ...            ...
# 10711       10711  HP OfficeJet Pro 9025e   Amazon  2021-05-08              5
# 10712       10712  HP OfficeJet Pro 9025e   Amazon  2021-05-02              5
# 10713       10713  HP OfficeJet Pro 9025e   Amazon  2021-05-02              5
# 10714       10714  HP OfficeJet Pro 9025e   Amazon  2021-05-02              5
# 10716       10716  HP OfficeJet Pro 9025e   Amazon  2021-05-02              5
#
#                                            Review title  \
# 6388   Easy install and easy printing. Too proprietary.
# 6389   Easy install and easy printing. Too proprietary.
# 6390   Easy install and easy printing. Too proprietary.
# 6391   Easy install and easy printing. Too proprietary.
# 6401                                      Great Printer
# ...                                                 ...
# 10711                       Great for working from home
# 10712                          Really Nice, Great Setup
# 10713                          Really Nice, Great Setup
# 10714                          Really Nice, Great Setup
# 10716                          Really Nice, Great Setup
#
#                                           Review content  \
# 6388    Easy set up. Easy scanning. Didn’t join the i...
# 6389    Easy set up. Easy scanning. Didn’t join the i...
# 6390    Easy set up. Easy scanning. Didn’t join the i...
# 6391    Easy set up. Easy scanning. Didn’t join the i...
# 6401   After years of my old printer, purchased this ...
# ...                                                  ...
# 10711  This really is a great printer, and it's so mu...
# 10712  So the setup process with printers is normally...
# 10713  So the setup process with printers is normally...
# 10714  So the setup process with printers is normally...
# 10716  So the setup process with printers is normally...
#
#                                       Review concat text  Tokens  \
# 6388   Retailer: Amazon - Review model: HP OfficeJet ...     198
# 6389   Retailer: Amazon - Review model: HP OfficeJet ...     198
# 6390   Retailer: Amazon - Review model: HP OfficeJet ...     198
# 6391   Retailer: Amazon - Review model: HP OfficeJet ...     198
# 6401   Retailer: Amazon - Review model: HP OfficeJet ...      84
# ...                                                  ...     ...
# 10711  Retailer: Amazon - Review model: HP OfficeJet ...     268
# 10712  Retailer: Amazon - Review model: HP OfficeJet ...     132
# 10713  Retailer: Amazon - Review model: HP OfficeJet ...     132
# 10714  Retailer: Amazon - Review model: HP OfficeJet ...     132
# 10716  Retailer: Amazon - Review model: HP OfficeJet ...     132
#
#                                               key phrase  \
# 6388   [Easy setup, easy scanning, Proprietary restri...
# 6389   [Easy setup, easy scanning, Proprietary restri...
# 6390   [Easy setup, easy scanning, Proprietary restri...
# 6391   [Easy setup, easy scanning, Proprietary restri...
# 6401   [Fast printing, liked two tray feature, easy w...
# ...                                                  ...
# 10711  [Excellent for home office use, works seamless...
# 10712  [Easy setup process, App-based setup is conven...
# 10713  [Easy setup process, App-based setup is conven...
# 10714  [Easy setup process, App-based setup is conven...
# 10716  [Easy setup process, App-based setup is conven...
#
#                                                embedding  \
# 6388   [0.00624576723203063, 0.003082588315010071, 8....
# 6389   [0.00624576723203063, 0.003082588315010071, 8....
# 6390   [0.00624576723203063, 0.003082588315010071, 8....
# 6391   [0.00624576723203063, 0.003082588315010071, 8....
# 6401   [-0.03244659677147865, 0.009338131174445152, -...
# ...                                                  ...
# 10711  [-0.014914722181856632, 0.0015333282062783837,...
# 10712  [-0.016588890925049782, 0.017046066001057625, ...
# 10713  [-0.016588890925049782, 0.017046066001057625, ...
# 10714  [-0.016588890925049782, 0.017046066001057625, ...
# 10716  [-0.016588890925049782, 0.017046066001057625, ...
#
#                        key phrase splitted  \
# 6388                            Easy setup
# 6389                         easy scanning
# 6390              Proprietary restrictions
# 6391         Inflexibility with ink brands
# 6401                         Fast printing
# ...                                    ...
# 10711   positive response to free ink plan
# 10712                   Easy setup process
# 10713        App-based setup is convenient
# 10714        Supports multiple connections
# 10716                        user-friendly
#
#                                       embedding_splitted  \
# 6388   [0.0028877160511910915, 0.015896936878561974, ...
# 6389   [-0.04566308483481407, 0.025933345779776573, 0...
# 6390   [0.0037913022097200155, -0.012775414623320103,...
# 6391   [-0.0056190043687820435, 0.005538931582123041,...
# 6401   [-0.0462610200047493, 0.024372506886720657, -0...
# ...                                                  ...
# 10711  [-0.013421832583844662, -0.01247564610093832, ...
# 10712  [0.006355913821607828, 0.021701103076338768, 0...
# 10713  [-0.006079057231545448, 0.010124939493834972, ...
# 10714  [-0.038474854081869125, 0.005594192072749138, ...
# 10716  [-0.024744585156440735, 0.014936679974198341, ...
#
#                           Topic                                      Topic2
# 6388                      Setup                    Ink supply and Cartridge
# 6389                Ease of Use                    Ink supply and Cartridge
# 6390                   Firmware                    Ink supply and Cartridge
# 6391   Ink supply and Cartridge                    Ink supply and Cartridge
# 6401                Print Speed                                 Print Speed
# ...                         ...                                         ...
# 10711  Ink supply and Cartridge  Printer Hardware Robustness and sturdiness
# 10712                     Setup                                 Ease of Use
# 10713               Ease of Use                                 Ease of Use
# 10714              Connectivity                                 Ease of Use
# 10716               Ease of Use                                 Ease of Use
#
# [898 rows x 15 columns]
